# %% [markdown]
# # Chapter 4: Context Managers
#
# Context managers simplify resource management (files, locks, database connections). The `with` statement ensures proper setup and cleanup, even when exceptions occur.
